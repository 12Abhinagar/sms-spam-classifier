# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 80    ham                             Sorry, I'll call later        NaN
# 5202  ham           WOT STUDENT DISCOUNT CAN U GET ON BOOKS?        NaN
# 3842  ham  Yes ammae....life takes lot of turns you can o...        NaN
# 4592  ham  It's ok i wun b angry. Msg u aft i come home t...        NaN
# 3757  ham   Lol no ouch but wish i'd stayed out a bit longer        NaN
#
#      Unnamed: 3 Unnamed: 4
# 80          NaN        NaN
# 5202        NaN        NaN
# 3842        NaN        NaN
# 4592        NaN        NaN
# 3757        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.in
